# %%
import pandas as pd
import json 
import seaborn as sns

# %%
ls
# Out:
# CryptoPrices.py           Untitled.ipynb
# README.md                 sample_datacoin_cap.json

# %%
with open('sample_datacoin_cap.json') as fp:
    sample_data_coincap_json = json.load(fp)

# %%
sample_data_coincap_json
# Out:
# {'data': [{'id': 'bitcoin',
#    'rank': '1',
#    'symbol': 'BTC',
#    'name': 'Bitcoin',
#    'supply': '17193925.0000000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '119150835874.4699281625807300',
#    'volumeUsd24Hr': '2927959461.1750323310959460',
#    'priceUsd': '6929.8217756835584756',
#    'changePercent24Hr': '-0.8101417214350335',
#    'vwap24Hr': '7175.0663247679233209'},
#   {'id': 'ethereum',
#    'rank': '2',
#    'symbol': 'ETH',
#    'name': 'Ethereum',
#    'supply': '101160540.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '40967739219.6612727047843840',
#    'volumeUsd24Hr': '1026669440.6451482672850841',
#    'priceUsd': '404.9774667045200896',
#    'changePercent24Hr': '-0.0999626159535347',
#    'vwap24Hr': '415.3288028454417241'},
#   {'id': 'ripple',
#    'rank': '3',
#    'symbol': 'XRP',
#    'name': 'XRP',
#    'supply': '39299874590.0000000000000000',
#    'maxSupply': '100000000000.0000000000000000',
# ...

# %%
 
df_sample_data_copincap['priceUsd'] = df_sample_data_copincap['priceUsd'].astype('float')

# %%
df_sample_data_copincap.head()
# Out:
#              id rank symbol          name                        supply  \
# 0       bitcoin    1    BTC       Bitcoin     17193925.0000000000000000
# 1      ethereum    2    ETH      Ethereum    101160540.0000000000000000
# 2        ripple    3    XRP           XRP  39299874590.0000000000000000
# 3  bitcoin-cash    4    BCH  Bitcoin Cash     17278438.0000000000000000
# 4           eos    5    EOS           EOS    906245118.0000000000000000
#
#                        maxSupply                   marketCapUsd  \
# 0      21000000.0000000000000000  119150835874.4699281625807300
# 1                           None   40967739219.6612727047843840
# 2  100000000000.0000000000000000   16517228249.2902868380922380
# 3      21000000.0000000000000000   11902454455.1536127997298894
# 4    1000000000.0000000000000000    6327688685.5053582732768780
#
#                  volumeUsd24Hr     priceUsd    changePercent24Hr  \
# 0  2927959461.1750323310959460  6929.821776  -0.8101417214350335
# ...

# %%
df_sample_data_copincap.shape
# Out:
# (100, 11)

# %%
df_sample_data_copincap.columns.to_list()
# Out:
# ['id',
#  'rank',
#  'symbol',
#  'name',
#  'supply',
#  'maxSupply',
#  'marketCapUsd',
#  'volumeUsd24Hr',
#  'priceUsd',
#  'changePercent24Hr',
#  'vwap24Hr']

# %%
df_sample_data_copincap.dtypes
# Out:
# id                    object
# rank                  object
# symbol                object
# name                  object
# supply                object
# maxSupply             object
# marketCapUsd          object
# volumeUsd24Hr         object
# priceUsd             float64
# changePercent24Hr     object
# vwap24Hr              object
# dtype: object

# %%
df_sample_data_copincap.sort_values(by='priceUsd', ascending=False).head(5)
# Out:
#               id rank symbol          name                      supply  \
# 0        bitcoin    1    BTC       Bitcoin   17193925.0000000000000000
# 3   bitcoin-cash    4    BCH  Bitcoin Cash   17278438.0000000000000000
# 30         maker   31    MKR         Maker     668228.0000000000000000
# 1       ethereum    2    ETH      Ethereum  101160540.0000000000000000
# 14          dash   15   DASH          Dash    8242673.0000000000000000
#
#                     maxSupply                   marketCapUsd  \
# 0   21000000.0000000000000000  119150835874.4699281625807300
# 3   21000000.0000000000000000   11902454455.1536127997298894
# 30                       None     362174148.2486876620349236
# 1                        None   40967739219.6612727047843840
# 14  18900000.0000000000000000    1670555643.8854250757627516
#
#                   volumeUsd24Hr     priceUsd    changePercent24Hr  \
# 0   2927959461.1750323310959460  6929.821776  -0.8101417214350335
# ...

# %%
df_sample_data_copincap.sort_values(by='priceUsd', ascending=False).head(10).plot.bar(x='name', y='priceUsd')
# Out:
# <AxesSubplot:xlabel='name'>

# %%
tmp = df_sample_data_copincap.sort_values(by='priceUsd', ascending=False).head(5)
sns.barplot(x=tmp.name, y=tmp.priceUsd)
# Out:
# <AxesSubplot:xlabel='name', ylabel='priceUsd'>
